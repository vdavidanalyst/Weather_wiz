# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('./datasets/abuja.csv')
df2 = pd.read_csv('./datasets/keffi.csv')
df3 = pd.read_csv('./datasets/minna.csv')
df4 = pd.read_csv('./datasets/lagos.csv')

# %%
df1

# %%
df1['city'] = 'Abuja'

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91104 entries, 0 to 91103
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   time                       91104 non-null  object
#  1   temperature_2m (°C)        91033 non-null  float64
#  2   apparent_temperature (°C)  91033 non-null  float64
#  3   surface_pressure (hPa)     91033 non-null  float64
#  4   precipitation (mm)         91033 non-null  float64
#  5   rain (mm)                  91033 non-null  float64
#  6   cloudcover (%)             91033 non-null  float64
#  7   windspeed_10m (km/h)       91033 non-null  float64
#  8   winddirection_10m (°)      91033 non-null  float64
#  9   city                       91104 non-null  object
# dtypes: float64(8), object(2)
# memory usage: 7.0+ MB

# %%
df1.isna().sum()
# Out:
# time                          0
# temperature_2m (°C)          71
# apparent_temperature (°C)    71
# surface_pressure (hPa)       71
# precipitation (mm)           71
# rain (mm)                    71
# cloudcover (%)               71
# windspeed_10m (km/h)         71
# winddirection_10m (°)        71
# city                          0
# dtype: int64

# %%
df1.dropna(inplace = True)

# %%
df1.describe()
# Out:
#        temperature_2m (°C)  apparent_temperature (°C)  surface_pressure (hPa)  \
# count         91033.000000               91033.000000            91033.000000
# mean             26.898949                  29.163039              956.275578
# std               4.150406                   4.617022                1.972439
# min              16.500000                  12.100000              949.400000
# 25%              23.500000                  26.500000              954.900000
# 50%              26.100000                  29.200000              956.300000
# 75%              29.700000                  32.200000              957.700000
# max              40.000000                  42.100000              963.300000
#
#        precipitation (mm)     rain (mm)  cloudcover (%)  windspeed_10m (km/h)  \
# count        91033.000000  91033.000000    91033.000000          91033.000000
# mean             0.141704      0.141704       40.803796              5.820422
# ...

# %%
df2
# Out:
#                    time  temperature_2m (°C)  apparent_temperature (°C)  \
# 0      2013-01-01T00:00                 23.6                       20.3
# 1      2013-01-01T01:00                 22.9                       19.5
# 2      2013-01-01T02:00                 22.4                       18.9
# 3      2013-01-01T03:00                 21.9                       18.5
# 4      2013-01-01T04:00                 21.4                       18.0
# ...                 ...                  ...                        ...
# 91099  2023-05-24T19:00                  NaN                        NaN
# 91100  2023-05-24T20:00                  NaN                        NaN
# 91101  2023-05-24T21:00                  NaN                        NaN
# 91102  2023-05-24T22:00                  NaN                        NaN
# 91103  2023-05-24T23:00                  NaN                        NaN
#
#        surface_pressure (hPa)  precipitation (mm)  rain (mm)  cloudcover (%)  \
# ...

# %%
df2['city'] = 'Keffi'

# %%
df2.isna().sum()
# Out:
# time                          0
# temperature_2m (°C)          71
# apparent_temperature (°C)    71
# surface_pressure (hPa)       71
# precipitation (mm)           71
# rain (mm)                    71
# cloudcover (%)               71
# windspeed_10m (km/h)         71
# winddirection_10m (°)        71
# city                          0
# dtype: int64

# %%
df2.dropna(inplace=True)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 91033 entries, 0 to 91032
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   time                       91033 non-null  object
#  1   temperature_2m (°C)        91033 non-null  float64
#  2   apparent_temperature (°C)  91033 non-null  float64
#  3   surface_pressure (hPa)     91033 non-null  float64
#  4   precipitation (mm)         91033 non-null  float64
#  5   rain (mm)                  91033 non-null  float64
#  6   cloudcover (%)             91033 non-null  float64
#  7   windspeed_10m (km/h)       91033 non-null  float64
#  8   winddirection_10m (°)      91033 non-null  float64
#  9   city                       91033 non-null  object
# dtypes: float64(8), object(2)
# memory usage: 7.6+ MB

# %%
df2.describe()
# Out:
#        temperature_2m (°C)  apparent_temperature (°C)  surface_pressure (hPa)  \
# count         91033.000000               91033.000000            91033.000000
# mean             27.339375                  29.767688              972.572981
# std               4.201685                   4.639294                2.116468
# min              16.000000                  12.400000              965.100000
# 25%              23.900000                  27.000000              971.100000
# 50%              26.700000                  29.800000              972.600000
# 75%              30.200000                  32.900000              974.100000
# max              40.200000                  42.900000              980.000000
#
#        precipitation (mm)     rain (mm)  cloudcover (%)  windspeed_10m (km/h)  \
# count        91033.000000  91033.000000    91033.000000          91033.000000
# mean             0.121519      0.121519       41.236793              5.626905
# ...

# %%
df3
# Out:
#                    time  temperature_2m (°C)  apparent_temperature (°C)  \
# 0      2013-01-01T00:00                 23.6                       19.3
# 1      2013-01-01T01:00                 23.0                       18.7
# 2      2013-01-01T02:00                 22.4                       18.1
# 3      2013-01-01T03:00                 22.0                       17.6
# 4      2013-01-01T04:00                 21.6                       17.1
# ...                 ...                  ...                        ...
# 91099  2023-05-24T19:00                  NaN                        NaN
# 91100  2023-05-24T20:00                  NaN                        NaN
# 91101  2023-05-24T21:00                  NaN                        NaN
# 91102  2023-05-24T22:00                  NaN                        NaN
# 91103  2023-05-24T23:00                  NaN                        NaN
#
#        surface_pressure (hPa)  precipitation (mm)  rain (mm)  cloudcover (%)  \
# ...

# %%
df3['city'] = 'Minna'

# %%
df3.isna().sum()
# Out:
# time                          0
# temperature_2m (°C)          71
# apparent_temperature (°C)    71
# surface_pressure (hPa)       71
# precipitation (mm)           71
# rain (mm)                    71
# cloudcover (%)               71
# windspeed_10m (km/h)         71
# winddirection_10m (°)        71
# city                          0
# dtype: int64

# %%
df3.dropna(inplace=True)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 91033 entries, 0 to 91032
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   time                       91033 non-null  object
#  1   temperature_2m (°C)        91033 non-null  float64
#  2   apparent_temperature (°C)  91033 non-null  float64
#  3   surface_pressure (hPa)     91033 non-null  float64
#  4   precipitation (mm)         91033 non-null  float64
#  5   rain (mm)                  91033 non-null  float64
#  6   cloudcover (%)             91033 non-null  float64
#  7   windspeed_10m (km/h)       91033 non-null  float64
#  8   winddirection_10m (°)      91033 non-null  float64
#  9   city                       91033 non-null  object
# dtypes: float64(8), object(2)
# memory usage: 7.6+ MB

# %%
df3.describe()
# Out:
#        temperature_2m (°C)  apparent_temperature (°C)  surface_pressure (hPa)  \
# count         91033.000000               91033.000000            91033.000000
# mean             28.310529                  30.420111              981.997109
# std               4.320639                   5.119868                2.204771
# min              17.100000                  12.000000              974.000000
# 25%              24.800000                  27.500000              980.500000
# 50%              27.600000                  30.600000              982.100000
# 75%              31.200000                  33.900000              983.600000
# max              41.800000                  44.600000              989.500000
#
#        precipitation (mm)     rain (mm)  cloudcover (%)  windspeed_10m (km/h)  \
# count        91033.000000  91033.000000    91033.000000          91033.000000
# mean             0.109902      0.109902       35.985071              7.340674
# ...

# %%
df4
# Out:
#                    time  temperature_2m (°C)  apparent_temperature (°C)  \
# 0      2013-01-01T00:00                 26.8                       32.1
# 1      2013-01-01T01:00                 26.6                       32.6
# 2      2013-01-01T02:00                 25.8                       31.5
# 3      2013-01-01T03:00                 25.1                       30.3
# 4      2013-01-01T04:00                 25.0                       30.0
# ...                 ...                  ...                        ...
# 91099  2023-05-24T19:00                  NaN                        NaN
# 91100  2023-05-24T20:00                  NaN                        NaN
# 91101  2023-05-24T21:00                  NaN                        NaN
# 91102  2023-05-24T22:00                  NaN                        NaN
# 91103  2023-05-24T23:00                  NaN                        NaN
#
#        surface_pressure (hPa)  precipitation (mm)  rain (mm)  cloudcover (%)  \
# ...

# %%
df4['city'] = 'Lagos'

# %%
df4.isna().sum()
# Out:
# time                          0
# temperature_2m (°C)          71
# apparent_temperature (°C)    71
# surface_pressure (hPa)       71
# precipitation (mm)           71
# rain (mm)                    71
# cloudcover (%)               71
# windspeed_10m (km/h)         71
# winddirection_10m (°)        71
# city                          0
# dtype: int64

# %%
df4.isna().sum()
# Out:
# time                          0
# temperature_2m (°C)          71
# apparent_temperature (°C)    71
# surface_pressure (hPa)       71
# precipitation (mm)           71
# rain (mm)                    71
# cloudcover (%)               71
# windspeed_10m (km/h)         71
# winddirection_10m (°)        71
# city                          0
# dtype: int64

# %%
df4.dropna(inplace=True)

# %%
df4.describe()
# Out:
#        temperature_2m (°C)  apparent_temperature (°C)  surface_pressure (hPa)  \
# count         91033.000000               91033.000000            91033.000000
# mean             26.818935                  31.125061             1010.425374
# std               1.976790                   2.550286                2.113804
# min              18.600000                  17.500000             1003.400000
# 25%              25.400000                  29.400000             1008.900000
# 50%              26.600000                  31.200000             1010.400000
# 75%              27.900000                  32.600000             1011.900000
# max              34.300000                  40.100000             1018.200000
#
#        precipitation (mm)     rain (mm)  cloudcover (%)  windspeed_10m (km/h)  \
# count        91033.000000  91033.000000    91033.000000          91033.000000
# mean             0.179365      0.179365       51.815221             11.615750
# ...

# %%
# Concatenate all four DataFrames vertically
df = pd.concat([df1, df2, df3, df4], axis=0)

# %%
df
# Out:
#                    time  temperature_2m (°C)  apparent_temperature (°C)  \
# 0      2013-01-01T00:00                 22.9                       18.8
# 1      2013-01-01T01:00                 22.3                       18.3
# 2      2013-01-01T02:00                 21.8                       17.8
# 3      2013-01-01T03:00                 21.4                       17.5
# 4      2013-01-01T04:00                 21.0                       17.0
# ...                 ...                  ...                        ...
# 91028  2023-05-21T20:00                 27.5                       31.5
# 91029  2023-05-21T21:00                 27.4                       31.5
# 91030  2023-05-21T22:00                 27.2                       31.7
# 91031  2023-05-21T23:00                 27.1                       32.4
# 91032  2023-05-22T00:00                 27.0                       32.0
#
#        surface_pressure (hPa)  precipitation (mm)  rain (mm)  cloudcover (%)  \
# ...

# %%
df.isna().sum()
# Out:
# time                         0
# temperature_2m (°C)          0
# apparent_temperature (°C)    0
# surface_pressure (hPa)       0
# precipitation (mm)           0
# rain (mm)                    0
# cloudcover (%)               0
# windspeed_10m (km/h)         0
# winddirection_10m (°)        0
# city                         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.to_csv('final data.csv', index=False)
